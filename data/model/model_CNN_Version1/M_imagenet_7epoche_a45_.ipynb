# %%
import keras
import tensorflow as tf
from keras.models import Sequential
from keras import datasets, layers, models
from keras.utils import np_utils
from keras import regularizers
from keras.layers import Dense, Dropout, BatchNormalization
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation
#from tensorflow.python.keras.optimizers import Adam, RMSprop
#from tensorflow.python.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from numpy import loadtxt
import tensorflow.keras
from PIL import Image, ImageOps
# %matplotlib inline
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from imutils import paths
# %matplotlib inline

# %%
# !git clone https://github.com/mohammedtlili/truck_recommandation.git
# Out:
# Cloning into 'truck_recommandation'...
# remote: Enumerating objects: 17852, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 17852 (delta 4), reused 8 (delta 0), pack-reused 17834
# Receiving objects: 100% (17852/17852), 121.27 MiB | 31.18 MiB/s, done.
# Resolving deltas: 100% (25/25), done.
# Checking out files: 100% (19175/19175), done.

# %%
# used from keras documentation (flow_from_directory method)

batch_size = 32
image_size = 128

# %%
## Create image generator
# folders with train dir & val dir
train_dir = '/content/truck_recommandation/dataset/train_set'
test_dir = '/content/truck_recommandation/dataset/test_set'
testing_dir = '/content/truck_recommandation/dataset/single_prediction'
input_shape = (image_size, image_size, 3)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, History
import os

# %%
#os.mkdir('model')
os.makedirs('model', exist_ok=True)

# %%
#Model saving based on validation accuracy score
filepath="model/M_categoriel-{val_accuracy:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_accuracy',  verbose=1, save_best_only=True, mode='auto')

# %%
# image augmentation technique to enrich our dataset(training set) without adding more images
# so get good performance  results with little or no overfitting even with the small amount of images
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1. / 255,
                              samplewise_center=True, 
                              samplewise_std_normalization=True, 
                              horizontal_flip = True, 
                              vertical_flip = False, 
                              height_shift_range= 0.05, 
                              width_shift_range=0.2, 
                              rotation_range=5, 
                              shear_range = 0.1,
                              fill_mode = 'reflect',
                              zoom_range=0)

test_datagen = ImageDataGenerator(rescale=1. / 255,
                              samplewise_center=True, 
                              samplewise_std_normalization=True, 
                              horizontal_flip = True, 
                              vertical_flip = False, 
                              height_shift_range= 0.05, 
                              width_shift_range=0.2, 
                              rotation_range=5, 
                              shear_range = 0.1,
                              fill_mode = 'reflect',
                              zoom_range=0)

# %%
img_path = '/content/truck_recommandation/dataset/train_set/camionette/Sans-titre-1-17.jpg'
img = image.load_img(img_path, target_size=(128, 128))
x = image.img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0
for batch in train_datagen.flow(x, batch_size=1):
    plt.figure(i)
    imgplot = plt.imshow(image.array_to_img(batch[0]))
    i += 1
    if i % 6 == 0:
        break
plt.show()

# %%
# create training set
# wanna get higher accuracy -> inccrease target_size
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(image_size, image_size),
    batch_size=batch_size,
    class_mode='categorical')
# Out:
# Found 14240 images belonging to 4 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1. / 255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(image_size, image_size),
    batch_size=batch_size,
    class_mode='categorical')
# Out:
# Found 3560 images belonging to 4 classes.

# %%
testing_datagen = ImageDataGenerator(rescale=1. / 255)

testing_generator = testing_datagen.flow_from_directory(
    testing_dir,
    target_size=(image_size, image_size),
    batch_size=batch_size,
    shuffle=False,
    class_mode='categorical')
# Out:
# Found 0 images belonging to 0 classes.

# %%
train_generator.class_indices
# Out:
# {'camionette': 0, 'fourgon': 1, 'porteur': 2, 'utilitaire': 3}

# %%
from sklearn.utils.class_weight import compute_class_weight
cls_train = train_generator.classes
from collections import OrderedDict
classes = list(train_generator.class_indices.keys())
num_values = []
unique, counts = np.unique(cls_train, return_counts=True)
valdict=OrderedDict(zip(unique, counts))
for i in range(4):
    num_values.append(valdict[i])
plt.figure(figsize=(10,10))
x = np.arange(len(num_values))
xlabel = classes
plt.bar(x, num_values)
plt.xticks(x, xlabel)
plt.show()

# %%
import matplotlib.pyplot as plt
goal_types = list(train_generator.class_indices.keys())
unique, counts = np.unique(cls_train, return_counts=True)
goals = [(counts)]
colors = ['y','r','b','g']
plt.pie(goals, labels = goal_types, colors=colors ,shadow = True, explode = (0.05, 0.05, 0.05, 0.05), autopct = '%1.1f%%')
plt.axis('equal')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.

# %%
from sklearn.utils.class_weight import compute_class_weight
cls_test = test_generator.classes
from collections import OrderedDict


classes = list(test_generator.class_indices.keys())
print(classes)
num_values = []
print(num_values)

unique, counts = np.unique(cls_test, return_counts=True)
valdict=OrderedDict(zip(unique, counts))
print(valdict)

for i in range(4):
  num_values.append(valdict[i])
plt.figure(figsize=(10,10))
x = np.arange(len(num_values))
xlabel = classes
plt.bar(x, num_values)
plt.xticks(x, xlabel)
plt.show()
# Out:
# ['camionette', 'fourgon', 'porteur', 'utilitaire']
# []
# OrderedDict([(0, 890), (1, 890), (2, 890), (3, 890)])

# %%
import matplotlib.pyplot as plt

goal_types = list(test_generator.class_indices.keys())
unique, counts = np.unique(cls_test, return_counts=True)
goals = [(counts)]
colors = ['y','r','b','g']

plt.pie(goals, labels = goal_types, colors=colors ,shadow = True, explode = (0.05, 0.05, 0.05, 0.05), autopct = '%1.1f%%')
plt.axis('equal')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.

# %%
# Download InceptionV3 model
pretrained_model = InceptionV3(weights='imagenet', include_top=False)
pretrained_model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv2d_94 (Conv2D)             (None, None, None,   864         ['input_2[0][0]']
#                                 32)
#
#  batch_normalization_96 (BatchN  (None, None, None,   96         ['conv2d_94[0][0]']
#  ormalization)                  32)
#
#  activation_98 (Activation)     (None, None, None,   0           ['batch_normalization_96[0][0]']
#                                 32)
#
#  conv2d_95 (Conv2D)             (None, None, None,   9216        ['activation_98[0][0]']
#                                 32)
#
#  batch_normalization_97 (BatchN  (None, None, None,   96         ['conv2d_95[0][0]']
#  ormalization)                  32)
#
#  activation_99 (Activation)     (None, None, None,   0           ['batch_normalization_97[0][0]']
#                                 32)
#
#  conv2d_96 (Conv2D)             (None, None, None,   18432       ['activation_99[0][0]']
#                                 64)
#
#  batch_normalization_98 (BatchN  (None, None, None,   192        ['conv2d_96[0][0]']
#  ormalization)                  64)
#
#  activation_100 (Activation)    (None, None, None,   0           ['batch_normalization_98[0][0]']
#                                 64)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, None, None,   0          ['activation_100[0][0]']
#                                 64)
#
#  conv2d_97 (Conv2D)             (None, None, None,   5120        ['max_pooling2d_4[0][0]']
#                                 80)
#
#  batch_normalization_99 (BatchN  (None, None, None,   240        ['conv2d_97[0][0]']
#  ormalization)                  80)
#
#  activation_101 (Activation)    (None, None, None,   0           ['batch_normalization_99[0][0]']
#                                 80)
#
#  conv2d_98 (Conv2D)             (None, None, None,   138240      ['activation_101[0][0]']
#                                 192)
#
#  batch_normalization_100 (Batch  (None, None, None,   576        ['conv2d_98[0][0]']
#  Normalization)                 192)
#
#  activation_102 (Activation)    (None, None, None,   0           ['batch_normalization_100[0][0]']
#                                 192)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, None, None,   0          ['activation_102[0][0]']
#                                 192)
#
#  conv2d_102 (Conv2D)            (None, None, None,   12288       ['max_pooling2d_5[0][0]']
#                                 64)
#
#  batch_normalization_104 (Batch  (None, None, None,   192        ['conv2d_102[0][0]']
#  Normalization)                 64)
#
#  activation_106 (Activation)    (None, None, None,   0           ['batch_normalization_104[0][0]']
#                                 64)
#
#  conv2d_100 (Conv2D)            (None, None, None,   9216        ['max_pooling2d_5[0][0]']
#                                 48)
#
#  conv2d_103 (Conv2D)            (None, None, None,   55296       ['activation_106[0][0]']
#                                 96)
#
#  batch_normalization_102 (Batch  (None, None, None,   144        ['conv2d_100[0][0]']
#  Normalization)                 48)
#
#  batch_normalization_105 (Batch  (None, None, None,   288        ['conv2d_103[0][0]']
#  Normalization)                 96)
#
#  activation_104 (Activation)    (None, None, None,   0           ['batch_normalization_102[0][0]']
#                                 48)
#
#  activation_107 (Activation)    (None, None, None,   0           ['batch_normalization_105[0][0]']
#                                 96)
#
#  average_pooling2d_9 (AveragePo  (None, None, None,   0          ['max_pooling2d_5[0][0]']
#  oling2D)                       192)
#
#  conv2d_99 (Conv2D)             (None, None, None,   12288       ['max_pooling2d_5[0][0]']
#                                 64)
#
#  conv2d_101 (Conv2D)            (None, None, None,   76800       ['activation_104[0][0]']
#                                 64)
#
#  conv2d_104 (Conv2D)            (None, None, None,   82944       ['activation_107[0][0]']
#                                 96)
#
#  conv2d_105 (Conv2D)            (None, None, None,   6144        ['average_pooling2d_9[0][0]']
#                                 32)
#
#  batch_normalization_101 (Batch  (None, None, None,   192        ['conv2d_99[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_103 (Batch  (None, None, None,   192        ['conv2d_101[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_106 (Batch  (None, None, None,   288        ['conv2d_104[0][0]']
#  Normalization)                 96)
#
#  batch_normalization_107 (Batch  (None, None, None,   96         ['conv2d_105[0][0]']
#  Normalization)                 32)
#
#  activation_103 (Activation)    (None, None, None,   0           ['batch_normalization_101[0][0]']
#                                 64)
#
#  activation_105 (Activation)    (None, None, None,   0           ['batch_normalization_103[0][0]']
#                                 64)
#
#  activation_108 (Activation)    (None, None, None,   0           ['batch_normalization_106[0][0]']
#                                 96)
#
#  activation_109 (Activation)    (None, None, None,   0           ['batch_normalization_107[0][0]']
#                                 32)
#
#  mixed0 (Concatenate)           (None, None, None,   0           ['activation_103[0][0]',
#                                 256)                              'activation_105[0][0]',
#                                                                   'activation_108[0][0]',
#                                                                   'activation_109[0][0]']
#
#  conv2d_109 (Conv2D)            (None, None, None,   16384       ['mixed0[0][0]']
#                                 64)
#
#  batch_normalization_111 (Batch  (None, None, None,   192        ['conv2d_109[0][0]']
#  Normalization)                 64)
#
#  activation_113 (Activation)    (None, None, None,   0           ['batch_normalization_111[0][0]']
#                                 64)
#
#  conv2d_107 (Conv2D)            (None, None, None,   12288       ['mixed0[0][0]']
#                                 48)
#
#  conv2d_110 (Conv2D)            (None, None, None,   55296       ['activation_113[0][0]']
#                                 96)
#
#  batch_normalization_109 (Batch  (None, None, None,   144        ['conv2d_107[0][0]']
#  Normalization)                 48)
#
#  batch_normalization_112 (Batch  (None, None, None,   288        ['conv2d_110[0][0]']
#  Normalization)                 96)
#
#  activation_111 (Activation)    (None, None, None,   0           ['batch_normalization_109[0][0]']
#                                 48)
#
#  activation_114 (Activation)    (None, None, None,   0           ['batch_normalization_112[0][0]']
#                                 96)
#
#  average_pooling2d_10 (AverageP  (None, None, None,   0          ['mixed0[0][0]']
#  ooling2D)                      256)
#
#  conv2d_106 (Conv2D)            (None, None, None,   16384       ['mixed0[0][0]']
#                                 64)
#
#  conv2d_108 (Conv2D)            (None, None, None,   76800       ['activation_111[0][0]']
#                                 64)
#
#  conv2d_111 (Conv2D)            (None, None, None,   82944       ['activation_114[0][0]']
#                                 96)
#
#  conv2d_112 (Conv2D)            (None, None, None,   16384       ['average_pooling2d_10[0][0]']
#                                 64)
#
#  batch_normalization_108 (Batch  (None, None, None,   192        ['conv2d_106[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_110 (Batch  (None, None, None,   192        ['conv2d_108[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_113 (Batch  (None, None, None,   288        ['conv2d_111[0][0]']
#  Normalization)                 96)
#
#  batch_normalization_114 (Batch  (None, None, None,   192        ['conv2d_112[0][0]']
#  Normalization)                 64)
#
#  activation_110 (Activation)    (None, None, None,   0           ['batch_normalization_108[0][0]']
#                                 64)
#
#  activation_112 (Activation)    (None, None, None,   0           ['batch_normalization_110[0][0]']
#                                 64)
#
#  activation_115 (Activation)    (None, None, None,   0           ['batch_normalization_113[0][0]']
#                                 96)
#
#  activation_116 (Activation)    (None, None, None,   0           ['batch_normalization_114[0][0]']
#                                 64)
#
#  mixed1 (Concatenate)           (None, None, None,   0           ['activation_110[0][0]',
#                                 288)                              'activation_112[0][0]',
#                                                                   'activation_115[0][0]',
#                                                                   'activation_116[0][0]']
#
#  conv2d_116 (Conv2D)            (None, None, None,   18432       ['mixed1[0][0]']
#                                 64)
#
#  batch_normalization_118 (Batch  (None, None, None,   192        ['conv2d_116[0][0]']
#  Normalization)                 64)
#
#  activation_120 (Activation)    (None, None, None,   0           ['batch_normalization_118[0][0]']
#                                 64)
#
#  conv2d_114 (Conv2D)            (None, None, None,   13824       ['mixed1[0][0]']
#                                 48)
#
#  conv2d_117 (Conv2D)            (None, None, None,   55296       ['activation_120[0][0]']
#                                 96)
#
#  batch_normalization_116 (Batch  (None, None, None,   144        ['conv2d_114[0][0]']
#  Normalization)                 48)
#
#  batch_normalization_119 (Batch  (None, None, None,   288        ['conv2d_117[0][0]']
#  Normalization)                 96)
#
#  activation_118 (Activation)    (None, None, None,   0           ['batch_normalization_116[0][0]']
#                                 48)
#
#  activation_121 (Activation)    (None, None, None,   0           ['batch_normalization_119[0][0]']
#                                 96)
#
#  average_pooling2d_11 (AverageP  (None, None, None,   0          ['mixed1[0][0]']
#  ooling2D)                      288)
#
#  conv2d_113 (Conv2D)            (None, None, None,   18432       ['mixed1[0][0]']
#                                 64)
#
#  conv2d_115 (Conv2D)            (None, None, None,   76800       ['activation_118[0][0]']
#                                 64)
#
#  conv2d_118 (Conv2D)            (None, None, None,   82944       ['activation_121[0][0]']
#                                 96)
#
#  conv2d_119 (Conv2D)            (None, None, None,   18432       ['average_pooling2d_11[0][0]']
#                                 64)
#
#  batch_normalization_115 (Batch  (None, None, None,   192        ['conv2d_113[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_117 (Batch  (None, None, None,   192        ['conv2d_115[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_120 (Batch  (None, None, None,   288        ['conv2d_118[0][0]']
#  Normalization)                 96)
#
#  batch_normalization_121 (Batch  (None, None, None,   192        ['conv2d_119[0][0]']
#  Normalization)                 64)
#
#  activation_117 (Activation)    (None, None, None,   0           ['batch_normalization_115[0][0]']
#                                 64)
#
#  activation_119 (Activation)    (None, None, None,   0           ['batch_normalization_117[0][0]']
#                                 64)
#
#  activation_122 (Activation)    (None, None, None,   0           ['batch_normalization_120[0][0]']
#                                 96)
#
#  activation_123 (Activation)    (None, None, None,   0           ['batch_normalization_121[0][0]']
#                                 64)
#
#  mixed2 (Concatenate)           (None, None, None,   0           ['activation_117[0][0]',
#                                 288)                              'activation_119[0][0]',
#                                                                   'activation_122[0][0]',
#                                                                   'activation_123[0][0]']
#
#  conv2d_121 (Conv2D)            (None, None, None,   18432       ['mixed2[0][0]']
#                                 64)
#
#  batch_normalization_123 (Batch  (None, None, None,   192        ['conv2d_121[0][0]']
#  Normalization)                 64)
#
#  activation_125 (Activation)    (None, None, None,   0           ['batch_normalization_123[0][0]']
#                                 64)
#
#  conv2d_122 (Conv2D)            (None, None, None,   55296       ['activation_125[0][0]']
#                                 96)
#
#  batch_normalization_124 (Batch  (None, None, None,   288        ['conv2d_122[0][0]']
#  Normalization)                 96)
#
#  activation_126 (Activation)    (None, None, None,   0           ['batch_normalization_124[0][0]']
#                                 96)
#
#  conv2d_120 (Conv2D)            (None, None, None,   995328      ['mixed2[0][0]']
#                                 384)
#
#  conv2d_123 (Conv2D)            (None, None, None,   82944       ['activation_126[0][0]']
#                                 96)
#
#  batch_normalization_122 (Batch  (None, None, None,   1152       ['conv2d_120[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_125 (Batch  (None, None, None,   288        ['conv2d_123[0][0]']
#  Normalization)                 96)
#
#  activation_124 (Activation)    (None, None, None,   0           ['batch_normalization_122[0][0]']
#                                 384)
#
#  activation_127 (Activation)    (None, None, None,   0           ['batch_normalization_125[0][0]']
#                                 96)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, None, None,   0          ['mixed2[0][0]']
#                                 288)
#
#  mixed3 (Concatenate)           (None, None, None,   0           ['activation_124[0][0]',
#                                 768)                              'activation_127[0][0]',
#                                                                   'max_pooling2d_6[0][0]']
#
#  conv2d_128 (Conv2D)            (None, None, None,   98304       ['mixed3[0][0]']
#                                 128)
#
#  batch_normalization_130 (Batch  (None, None, None,   384        ['conv2d_128[0][0]']
#  Normalization)                 128)
#
#  activation_132 (Activation)    (None, None, None,   0           ['batch_normalization_130[0][0]']
#                                 128)
#
#  conv2d_129 (Conv2D)            (None, None, None,   114688      ['activation_132[0][0]']
#                                 128)
#
#  batch_normalization_131 (Batch  (None, None, None,   384        ['conv2d_129[0][0]']
#  Normalization)                 128)
#
#  activation_133 (Activation)    (None, None, None,   0           ['batch_normalization_131[0][0]']
#                                 128)
#
#  conv2d_125 (Conv2D)            (None, None, None,   98304       ['mixed3[0][0]']
#                                 128)
#
#  conv2d_130 (Conv2D)            (None, None, None,   114688      ['activation_133[0][0]']
#                                 128)
#
#  batch_normalization_127 (Batch  (None, None, None,   384        ['conv2d_125[0][0]']
#  Normalization)                 128)
#
#  batch_normalization_132 (Batch  (None, None, None,   384        ['conv2d_130[0][0]']
#  Normalization)                 128)
#
#  activation_129 (Activation)    (None, None, None,   0           ['batch_normalization_127[0][0]']
#                                 128)
#
#  activation_134 (Activation)    (None, None, None,   0           ['batch_normalization_132[0][0]']
#                                 128)
#
#  conv2d_126 (Conv2D)            (None, None, None,   114688      ['activation_129[0][0]']
#                                 128)
#
#  conv2d_131 (Conv2D)            (None, None, None,   114688      ['activation_134[0][0]']
#                                 128)
#
#  batch_normalization_128 (Batch  (None, None, None,   384        ['conv2d_126[0][0]']
#  Normalization)                 128)
#
#  batch_normalization_133 (Batch  (None, None, None,   384        ['conv2d_131[0][0]']
#  Normalization)                 128)
#
#  activation_130 (Activation)    (None, None, None,   0           ['batch_normalization_128[0][0]']
#                                 128)
#
#  activation_135 (Activation)    (None, None, None,   0           ['batch_normalization_133[0][0]']
#                                 128)
#
#  average_pooling2d_12 (AverageP  (None, None, None,   0          ['mixed3[0][0]']
#  ooling2D)                      768)
#
#  conv2d_124 (Conv2D)            (None, None, None,   147456      ['mixed3[0][0]']
#                                 192)
#
#  conv2d_127 (Conv2D)            (None, None, None,   172032      ['activation_130[0][0]']
#                                 192)
#
#  conv2d_132 (Conv2D)            (None, None, None,   172032      ['activation_135[0][0]']
#                                 192)
#
#  conv2d_133 (Conv2D)            (None, None, None,   147456      ['average_pooling2d_12[0][0]']
#                                 192)
#
#  batch_normalization_126 (Batch  (None, None, None,   576        ['conv2d_124[0][0]']
#  Normalization)                 192)
#
#  batch_normalization_129 (Batch  (None, None, None,   576        ['conv2d_127[0][0]']
#  Normalization)                 192)
#
#  batch_normalization_134 (Batch  (None, None, None,   576        ['conv2d_132[0][0]']
#  Normalization)                 192)
#
#  batch_normalization_135 (Batch  (None, None, None,   576        ['conv2d_133[0][0]']
#  Normalization)                 192)
#
#  activation_128 (Activation)    (None, None, None,   0           ['batch_normalization_126[0][0]']
#                                 192)
#
#  activation_131 (Activation)    (None, None, None,   0           ['batch_normalization_129[0][0]']
#                                 192)
#
#  activation_136 (Activation)    (None, None, None,   0           ['batch_normalization_134[0][0]']
#                                 192)
#
#  activation_137 (Activation)    (None, None, None,   0           ['batch_normalization_135[0][0]']
#                                 192)
#
#  mixed4 (Concatenate)           (None, None, None,   0           ['activation_128[0][0]',
#                                 768)                              'activation_131[0][0]',
#                                                                   'activation_136[0][0]',
#                                                                   'activation_137[0][0]']
#
#  conv2d_138 (Conv2D)            (None, None, None,   122880      ['mixed4[0][0]']
#                                 160)
#
#  batch_normalization_140 (Batch  (None, None, None,   480        ['conv2d_138[0][0]']
#  Normalization)                 160)
#
#  activation_142 (Activation)    (None, None, None,   0           ['batch_normalization_140[0][0]']
#                                 160)
#
#  conv2d_139 (Conv2D)            (None, None, None,   179200      ['activation_142[0][0]']
#                                 160)
#
#  batch_normalization_141 (Batch  (None, None, None,   480        ['conv2d_139[0][0]']
#  Normalization)                 160)
#
#  activation_143 (Activation)    (None, None, None,   0           ['batch_normalization_141[0][0]']
#                                 160)
#
#  conv2d_135 (Conv2D)            (None, None, None,   122880      ['mixed4[0][0]']
#                                 160)
#
#  conv2d_140 (Conv2D)            (None, None, None,   179200      ['activation_143[0][0]']
#                                 160)
#
#  batch_normalization_137 (Batch  (None, None, None,   480        ['conv2d_135[0][0]']
#  Normalization)                 160)
#
#  batch_normalization_142 (Batch  (None, None, None,   480        ['conv2d_140[0][0]']
#  Normalization)                 160)
#
#  activation_139 (Activation)    (None, None, None,   0           ['batch_normalization_137[0][0]']
#                                 160)
#
#  activation_144 (Activation)    (None, None, None,   0           ['batch_normalization_142[0][0]']
#                                 160)
#
#  conv2d_136 (Conv2D)            (None, None, None,   179200      ['activation_139[0][0]']
#                                 160)
#
#  conv2d_141 (Conv2D)            (None, None, None,   179200      ['activation_144[0][0]']
#                                 160)
#
#  batch_normalization_138 (Batch  (None, None, None,   480        ['conv2d_136[0][0]']
#  Normalization)                 160)
#
#  batch_normalization_143 (Batch  (None, None, None,   480        ['conv2d_141[0][0]']
#  Normalization)                 160)
#
#  activation_140 (Activation)    (None, None, None,   0           ['batch_normalization_138[0][0]']
#                                 160)
#
#  activation_145 (Activation)    (None, None, None,   0           ['batch_normalization_143[0][0]']
#                                 160)
#
#  average_pooling2d_13 (AverageP  (None, None, None,   0          ['mixed4[0][0]']
#  ooling2D)                      768)
#
#  conv2d_134 (Conv2D)            (None, None, None,   147456      ['mixed4[0][0]']
#                                 192)
#
#  conv2d_137 (Conv2D)            (None, None, None,   215040      ['activation_140[0][0]']
#                                 192)
#
#  conv2d_142 (Conv2D)            (None, None, None,   215040      ['activation_145[0][0]']
#                                 192)
#
#  conv2d_143 (Conv2D)            (None, None, None,   147456      ['average_pooling2d_13[0][0]']
#                                 192)
#
#  batch_normalization_136 (Batch  (None, None, None,   576        ['conv2d_134[0][0]']
#  Normalization)                 192)
#
#  batch_normalization_139 (Batch  (None, None, None,   576        ['conv2d_137[0][0]']
# ...
#
#  conv2d_176 (Conv2D)            (None, None, None,   442368      ['activation_179[0][0]']
#                                 384)
#
#  conv2d_177 (Conv2D)            (None, None, None,   442368      ['activation_179[0][0]']
#                                 384)
#
#  average_pooling2d_16 (AverageP  (None, None, None,   0          ['mixed8[0][0]']
#  ooling2D)                      1280)
#
#  conv2d_170 (Conv2D)            (None, None, None,   409600      ['mixed8[0][0]']
#                                 320)
#
#  batch_normalization_174 (Batch  (None, None, None,   1152       ['conv2d_172[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_175 (Batch  (None, None, None,   1152       ['conv2d_173[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_178 (Batch  (None, None, None,   1152       ['conv2d_176[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_179 (Batch  (None, None, None,   1152       ['conv2d_177[0][0]']
#  Normalization)                 384)
#
#  conv2d_178 (Conv2D)            (None, None, None,   245760      ['average_pooling2d_16[0][0]']
#                                 192)
#
#  batch_normalization_172 (Batch  (None, None, None,   960        ['conv2d_170[0][0]']
#  Normalization)                 320)
#
#  activation_176 (Activation)    (None, None, None,   0           ['batch_normalization_174[0][0]']
#                                 384)
#
#  activation_177 (Activation)    (None, None, None,   0           ['batch_normalization_175[0][0]']
#                                 384)
#
#  activation_180 (Activation)    (None, None, None,   0           ['batch_normalization_178[0][0]']
#                                 384)
#
#  activation_181 (Activation)    (None, None, None,   0           ['batch_normalization_179[0][0]']
#                                 384)
#
#  batch_normalization_180 (Batch  (None, None, None,   576        ['conv2d_178[0][0]']
#  Normalization)                 192)
#
#  activation_174 (Activation)    (None, None, None,   0           ['batch_normalization_172[0][0]']
#                                 320)
#
#  mixed9_0 (Concatenate)         (None, None, None,   0           ['activation_176[0][0]',
#                                 768)                              'activation_177[0][0]']
#
#  concatenate_2 (Concatenate)    (None, None, None,   0           ['activation_180[0][0]',
#                                 768)                              'activation_181[0][0]']
#
#  activation_182 (Activation)    (None, None, None,   0           ['batch_normalization_180[0][0]']
#                                 192)
#
#  mixed9 (Concatenate)           (None, None, None,   0           ['activation_174[0][0]',
#                                 2048)                             'mixed9_0[0][0]',
#                                                                   'concatenate_2[0][0]',
#                                                                   'activation_182[0][0]']
#
#  conv2d_183 (Conv2D)            (None, None, None,   917504      ['mixed9[0][0]']
#                                 448)
#
#  batch_normalization_185 (Batch  (None, None, None,   1344       ['conv2d_183[0][0]']
#  Normalization)                 448)
#
#  activation_187 (Activation)    (None, None, None,   0           ['batch_normalization_185[0][0]']
#                                 448)
#
#  conv2d_180 (Conv2D)            (None, None, None,   786432      ['mixed9[0][0]']
#                                 384)
#
#  conv2d_184 (Conv2D)            (None, None, None,   1548288     ['activation_187[0][0]']
#                                 384)
#
#  batch_normalization_182 (Batch  (None, None, None,   1152       ['conv2d_180[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_186 (Batch  (None, None, None,   1152       ['conv2d_184[0][0]']
#  Normalization)                 384)
#
#  activation_184 (Activation)    (None, None, None,   0           ['batch_normalization_182[0][0]']
#                                 384)
#
#  activation_188 (Activation)    (None, None, None,   0           ['batch_normalization_186[0][0]']
#                                 384)
#
#  conv2d_181 (Conv2D)            (None, None, None,   442368      ['activation_184[0][0]']
#                                 384)
#
#  conv2d_182 (Conv2D)            (None, None, None,   442368      ['activation_184[0][0]']
#                                 384)
#
#  conv2d_185 (Conv2D)            (None, None, None,   442368      ['activation_188[0][0]']
#                                 384)
#
#  conv2d_186 (Conv2D)            (None, None, None,   442368      ['activation_188[0][0]']
#                                 384)
#
#  average_pooling2d_17 (AverageP  (None, None, None,   0          ['mixed9[0][0]']
#  ooling2D)                      2048)
#
#  conv2d_179 (Conv2D)            (None, None, None,   655360      ['mixed9[0][0]']
#                                 320)
#
#  batch_normalization_183 (Batch  (None, None, None,   1152       ['conv2d_181[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_184 (Batch  (None, None, None,   1152       ['conv2d_182[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_187 (Batch  (None, None, None,   1152       ['conv2d_185[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_188 (Batch  (None, None, None,   1152       ['conv2d_186[0][0]']
#  Normalization)                 384)
#
#  conv2d_187 (Conv2D)            (None, None, None,   393216      ['average_pooling2d_17[0][0]']
#                                 192)
#
#  batch_normalization_181 (Batch  (None, None, None,   960        ['conv2d_179[0][0]']
#  Normalization)                 320)
#
#  activation_185 (Activation)    (None, None, None,   0           ['batch_normalization_183[0][0]']
#                                 384)
#
#  activation_186 (Activation)    (None, None, None,   0           ['batch_normalization_184[0][0]']
#                                 384)
#
#  activation_189 (Activation)    (None, None, None,   0           ['batch_normalization_187[0][0]']
#                                 384)
#
#  activation_190 (Activation)    (None, None, None,   0           ['batch_normalization_188[0][0]']
#                                 384)
#
#  batch_normalization_189 (Batch  (None, None, None,   576        ['conv2d_187[0][0]']
#  Normalization)                 192)
#
#  activation_183 (Activation)    (None, None, None,   0           ['batch_normalization_181[0][0]']
#                                 320)
#
#  mixed9_1 (Concatenate)         (None, None, None,   0           ['activation_185[0][0]',
#                                 768)                              'activation_186[0][0]']
#
#  concatenate_3 (Concatenate)    (None, None, None,   0           ['activation_189[0][0]',
#                                 768)                              'activation_190[0][0]']
#
#  activation_191 (Activation)    (None, None, None,   0           ['batch_normalization_189[0][0]']
#                                 192)
#
#  mixed10 (Concatenate)          (None, None, None,   0           ['activation_183[0][0]',
#                                 2048)                             'mixed9_1[0][0]',
#                                                                   'concatenate_3[0][0]',
#                                                                   'activation_191[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
pretrained_model.trainable = False
pretrained_model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv2d (Conv2D)                (None, None, None,   864         ['input_1[0][0]']
#                                 32)
#
#  batch_normalization (BatchNorm  (None, None, None,   96         ['conv2d[0][0]']
#  alization)                     32)
#
#  activation (Activation)        (None, None, None,   0           ['batch_normalization[0][0]']
#                                 32)
#
#  conv2d_1 (Conv2D)              (None, None, None,   9216        ['activation[0][0]']
#                                 32)
#
#  batch_normalization_1 (BatchNo  (None, None, None,   96         ['conv2d_1[0][0]']
#  rmalization)                   32)
#
#  activation_1 (Activation)      (None, None, None,   0           ['batch_normalization_1[0][0]']
#                                 32)
#
#  conv2d_2 (Conv2D)              (None, None, None,   18432       ['activation_1[0][0]']
#                                 64)
#
#  batch_normalization_2 (BatchNo  (None, None, None,   192        ['conv2d_2[0][0]']
#  rmalization)                   64)
#
#  activation_2 (Activation)      (None, None, None,   0           ['batch_normalization_2[0][0]']
#                                 64)
#
#  max_pooling2d (MaxPooling2D)   (None, None, None,   0           ['activation_2[0][0]']
#                                 64)
#
#  conv2d_3 (Conv2D)              (None, None, None,   5120        ['max_pooling2d[0][0]']
#                                 80)
#
#  batch_normalization_3 (BatchNo  (None, None, None,   240        ['conv2d_3[0][0]']
#  rmalization)                   80)
#
#  activation_3 (Activation)      (None, None, None,   0           ['batch_normalization_3[0][0]']
#                                 80)
#
#  conv2d_4 (Conv2D)              (None, None, None,   138240      ['activation_3[0][0]']
#                                 192)
#
#  batch_normalization_4 (BatchNo  (None, None, None,   576        ['conv2d_4[0][0]']
#  rmalization)                   192)
#
#  activation_4 (Activation)      (None, None, None,   0           ['batch_normalization_4[0][0]']
#                                 192)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, None, None,   0          ['activation_4[0][0]']
#                                 192)
#
#  conv2d_8 (Conv2D)              (None, None, None,   12288       ['max_pooling2d_1[0][0]']
#                                 64)
#
#  batch_normalization_8 (BatchNo  (None, None, None,   192        ['conv2d_8[0][0]']
#  rmalization)                   64)
#
#  activation_8 (Activation)      (None, None, None,   0           ['batch_normalization_8[0][0]']
#                                 64)
#
#  conv2d_6 (Conv2D)              (None, None, None,   9216        ['max_pooling2d_1[0][0]']
#                                 48)
#
#  conv2d_9 (Conv2D)              (None, None, None,   55296       ['activation_8[0][0]']
#                                 96)
#
#  batch_normalization_6 (BatchNo  (None, None, None,   144        ['conv2d_6[0][0]']
#  rmalization)                   48)
#
#  batch_normalization_9 (BatchNo  (None, None, None,   288        ['conv2d_9[0][0]']
#  rmalization)                   96)
#
#  activation_6 (Activation)      (None, None, None,   0           ['batch_normalization_6[0][0]']
#                                 48)
#
#  activation_9 (Activation)      (None, None, None,   0           ['batch_normalization_9[0][0]']
#                                 96)
#
#  average_pooling2d (AveragePool  (None, None, None,   0          ['max_pooling2d_1[0][0]']
#  ing2D)                         192)
#
#  conv2d_5 (Conv2D)              (None, None, None,   12288       ['max_pooling2d_1[0][0]']
#                                 64)
#
#  conv2d_7 (Conv2D)              (None, None, None,   76800       ['activation_6[0][0]']
#                                 64)
#
#  conv2d_10 (Conv2D)             (None, None, None,   82944       ['activation_9[0][0]']
#                                 96)
#
#  conv2d_11 (Conv2D)             (None, None, None,   6144        ['average_pooling2d[0][0]']
#                                 32)
#
#  batch_normalization_5 (BatchNo  (None, None, None,   192        ['conv2d_5[0][0]']
#  rmalization)                   64)
#
#  batch_normalization_7 (BatchNo  (None, None, None,   192        ['conv2d_7[0][0]']
#  rmalization)                   64)
#
#  batch_normalization_10 (BatchN  (None, None, None,   288        ['conv2d_10[0][0]']
#  ormalization)                  96)
#
#  batch_normalization_11 (BatchN  (None, None, None,   96         ['conv2d_11[0][0]']
#  ormalization)                  32)
#
#  activation_5 (Activation)      (None, None, None,   0           ['batch_normalization_5[0][0]']
#                                 64)
#
#  activation_7 (Activation)      (None, None, None,   0           ['batch_normalization_7[0][0]']
#                                 64)
#
#  activation_10 (Activation)     (None, None, None,   0           ['batch_normalization_10[0][0]']
#                                 96)
#
#  activation_11 (Activation)     (None, None, None,   0           ['batch_normalization_11[0][0]']
#                                 32)
#
#  mixed0 (Concatenate)           (None, None, None,   0           ['activation_5[0][0]',
#                                 256)                              'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, None, None,   16384       ['mixed0[0][0]']
#                                 64)
#
#  batch_normalization_15 (BatchN  (None, None, None,   192        ['conv2d_15[0][0]']
#  ormalization)                  64)
#
#  activation_15 (Activation)     (None, None, None,   0           ['batch_normalization_15[0][0]']
#                                 64)
#
#  conv2d_13 (Conv2D)             (None, None, None,   12288       ['mixed0[0][0]']
#                                 48)
#
#  conv2d_16 (Conv2D)             (None, None, None,   55296       ['activation_15[0][0]']
#                                 96)
#
#  batch_normalization_13 (BatchN  (None, None, None,   144        ['conv2d_13[0][0]']
#  ormalization)                  48)
#
#  batch_normalization_16 (BatchN  (None, None, None,   288        ['conv2d_16[0][0]']
#  ormalization)                  96)
#
#  activation_13 (Activation)     (None, None, None,   0           ['batch_normalization_13[0][0]']
#                                 48)
#
#  activation_16 (Activation)     (None, None, None,   0           ['batch_normalization_16[0][0]']
#                                 96)
#
#  average_pooling2d_1 (AveragePo  (None, None, None,   0          ['mixed0[0][0]']
#  oling2D)                       256)
#
#  conv2d_12 (Conv2D)             (None, None, None,   16384       ['mixed0[0][0]']
#                                 64)
#
#  conv2d_14 (Conv2D)             (None, None, None,   76800       ['activation_13[0][0]']
#                                 64)
#
#  conv2d_17 (Conv2D)             (None, None, None,   82944       ['activation_16[0][0]']
#                                 96)
#
#  conv2d_18 (Conv2D)             (None, None, None,   16384       ['average_pooling2d_1[0][0]']
#                                 64)
#
#  batch_normalization_12 (BatchN  (None, None, None,   192        ['conv2d_12[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_14 (BatchN  (None, None, None,   192        ['conv2d_14[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_17 (BatchN  (None, None, None,   288        ['conv2d_17[0][0]']
#  ormalization)                  96)
#
#  batch_normalization_18 (BatchN  (None, None, None,   192        ['conv2d_18[0][0]']
#  ormalization)                  64)
#
#  activation_12 (Activation)     (None, None, None,   0           ['batch_normalization_12[0][0]']
#                                 64)
#
#  activation_14 (Activation)     (None, None, None,   0           ['batch_normalization_14[0][0]']
#                                 64)
#
#  activation_17 (Activation)     (None, None, None,   0           ['batch_normalization_17[0][0]']
#                                 96)
#
#  activation_18 (Activation)     (None, None, None,   0           ['batch_normalization_18[0][0]']
#                                 64)
#
#  mixed1 (Concatenate)           (None, None, None,   0           ['activation_12[0][0]',
#                                 288)                              'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, None, None,   18432       ['mixed1[0][0]']
#                                 64)
#
#  batch_normalization_22 (BatchN  (None, None, None,   192        ['conv2d_22[0][0]']
#  ormalization)                  64)
#
#  activation_22 (Activation)     (None, None, None,   0           ['batch_normalization_22[0][0]']
#                                 64)
#
#  conv2d_20 (Conv2D)             (None, None, None,   13824       ['mixed1[0][0]']
#                                 48)
#
#  conv2d_23 (Conv2D)             (None, None, None,   55296       ['activation_22[0][0]']
#                                 96)
#
#  batch_normalization_20 (BatchN  (None, None, None,   144        ['conv2d_20[0][0]']
#  ormalization)                  48)
#
#  batch_normalization_23 (BatchN  (None, None, None,   288        ['conv2d_23[0][0]']
#  ormalization)                  96)
#
#  activation_20 (Activation)     (None, None, None,   0           ['batch_normalization_20[0][0]']
#                                 48)
#
#  activation_23 (Activation)     (None, None, None,   0           ['batch_normalization_23[0][0]']
#                                 96)
#
#  average_pooling2d_2 (AveragePo  (None, None, None,   0          ['mixed1[0][0]']
#  oling2D)                       288)
#
#  conv2d_19 (Conv2D)             (None, None, None,   18432       ['mixed1[0][0]']
#                                 64)
#
#  conv2d_21 (Conv2D)             (None, None, None,   76800       ['activation_20[0][0]']
#                                 64)
#
#  conv2d_24 (Conv2D)             (None, None, None,   82944       ['activation_23[0][0]']
#                                 96)
#
#  conv2d_25 (Conv2D)             (None, None, None,   18432       ['average_pooling2d_2[0][0]']
#                                 64)
#
#  batch_normalization_19 (BatchN  (None, None, None,   192        ['conv2d_19[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_21 (BatchN  (None, None, None,   192        ['conv2d_21[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_24 (BatchN  (None, None, None,   288        ['conv2d_24[0][0]']
#  ormalization)                  96)
#
#  batch_normalization_25 (BatchN  (None, None, None,   192        ['conv2d_25[0][0]']
#  ormalization)                  64)
#
#  activation_19 (Activation)     (None, None, None,   0           ['batch_normalization_19[0][0]']
#                                 64)
#
#  activation_21 (Activation)     (None, None, None,   0           ['batch_normalization_21[0][0]']
#                                 64)
#
#  activation_24 (Activation)     (None, None, None,   0           ['batch_normalization_24[0][0]']
#                                 96)
#
#  activation_25 (Activation)     (None, None, None,   0           ['batch_normalization_25[0][0]']
#                                 64)
#
#  mixed2 (Concatenate)           (None, None, None,   0           ['activation_19[0][0]',
#                                 288)                              'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, None, None,   18432       ['mixed2[0][0]']
#                                 64)
#
#  batch_normalization_27 (BatchN  (None, None, None,   192        ['conv2d_27[0][0]']
#  ormalization)                  64)
#
#  activation_27 (Activation)     (None, None, None,   0           ['batch_normalization_27[0][0]']
#                                 64)
#
#  conv2d_28 (Conv2D)             (None, None, None,   55296       ['activation_27[0][0]']
#                                 96)
#
#  batch_normalization_28 (BatchN  (None, None, None,   288        ['conv2d_28[0][0]']
#  ormalization)                  96)
#
#  activation_28 (Activation)     (None, None, None,   0           ['batch_normalization_28[0][0]']
#                                 96)
#
#  conv2d_26 (Conv2D)             (None, None, None,   995328      ['mixed2[0][0]']
#                                 384)
#
#  conv2d_29 (Conv2D)             (None, None, None,   82944       ['activation_28[0][0]']
#                                 96)
#
#  batch_normalization_26 (BatchN  (None, None, None,   1152       ['conv2d_26[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_29 (BatchN  (None, None, None,   288        ['conv2d_29[0][0]']
#  ormalization)                  96)
#
#  activation_26 (Activation)     (None, None, None,   0           ['batch_normalization_26[0][0]']
#                                 384)
#
#  activation_29 (Activation)     (None, None, None,   0           ['batch_normalization_29[0][0]']
#                                 96)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, None, None,   0          ['mixed2[0][0]']
#                                 288)
#
#  mixed3 (Concatenate)           (None, None, None,   0           ['activation_26[0][0]',
#                                 768)                              'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, None, None,   98304       ['mixed3[0][0]']
#                                 128)
#
#  batch_normalization_34 (BatchN  (None, None, None,   384        ['conv2d_34[0][0]']
#  ormalization)                  128)
#
#  activation_34 (Activation)     (None, None, None,   0           ['batch_normalization_34[0][0]']
#                                 128)
#
#  conv2d_35 (Conv2D)             (None, None, None,   114688      ['activation_34[0][0]']
#                                 128)
#
#  batch_normalization_35 (BatchN  (None, None, None,   384        ['conv2d_35[0][0]']
#  ormalization)                  128)
#
#  activation_35 (Activation)     (None, None, None,   0           ['batch_normalization_35[0][0]']
#                                 128)
#
#  conv2d_31 (Conv2D)             (None, None, None,   98304       ['mixed3[0][0]']
#                                 128)
#
#  conv2d_36 (Conv2D)             (None, None, None,   114688      ['activation_35[0][0]']
#                                 128)
#
#  batch_normalization_31 (BatchN  (None, None, None,   384        ['conv2d_31[0][0]']
#  ormalization)                  128)
#
#  batch_normalization_36 (BatchN  (None, None, None,   384        ['conv2d_36[0][0]']
#  ormalization)                  128)
#
#  activation_31 (Activation)     (None, None, None,   0           ['batch_normalization_31[0][0]']
#                                 128)
#
#  activation_36 (Activation)     (None, None, None,   0           ['batch_normalization_36[0][0]']
#                                 128)
#
#  conv2d_32 (Conv2D)             (None, None, None,   114688      ['activation_31[0][0]']
#                                 128)
#
#  conv2d_37 (Conv2D)             (None, None, None,   114688      ['activation_36[0][0]']
#                                 128)
#
#  batch_normalization_32 (BatchN  (None, None, None,   384        ['conv2d_32[0][0]']
#  ormalization)                  128)
#
#  batch_normalization_37 (BatchN  (None, None, None,   384        ['conv2d_37[0][0]']
#  ormalization)                  128)
#
#  activation_32 (Activation)     (None, None, None,   0           ['batch_normalization_32[0][0]']
#                                 128)
#
#  activation_37 (Activation)     (None, None, None,   0           ['batch_normalization_37[0][0]']
#                                 128)
#
#  average_pooling2d_3 (AveragePo  (None, None, None,   0          ['mixed3[0][0]']
#  oling2D)                       768)
#
#  conv2d_30 (Conv2D)             (None, None, None,   147456      ['mixed3[0][0]']
#                                 192)
#
#  conv2d_33 (Conv2D)             (None, None, None,   172032      ['activation_32[0][0]']
#                                 192)
#
#  conv2d_38 (Conv2D)             (None, None, None,   172032      ['activation_37[0][0]']
#                                 192)
#
#  conv2d_39 (Conv2D)             (None, None, None,   147456      ['average_pooling2d_3[0][0]']
#                                 192)
#
#  batch_normalization_30 (BatchN  (None, None, None,   576        ['conv2d_30[0][0]']
#  ormalization)                  192)
#
#  batch_normalization_33 (BatchN  (None, None, None,   576        ['conv2d_33[0][0]']
#  ormalization)                  192)
#
#  batch_normalization_38 (BatchN  (None, None, None,   576        ['conv2d_38[0][0]']
#  ormalization)                  192)
#
#  batch_normalization_39 (BatchN  (None, None, None,   576        ['conv2d_39[0][0]']
#  ormalization)                  192)
#
#  activation_30 (Activation)     (None, None, None,   0           ['batch_normalization_30[0][0]']
#                                 192)
#
#  activation_33 (Activation)     (None, None, None,   0           ['batch_normalization_33[0][0]']
#                                 192)
#
#  activation_38 (Activation)     (None, None, None,   0           ['batch_normalization_38[0][0]']
#                                 192)
#
#  activation_39 (Activation)     (None, None, None,   0           ['batch_normalization_39[0][0]']
#                                 192)
#
#  mixed4 (Concatenate)           (None, None, None,   0           ['activation_30[0][0]',
#                                 768)                              'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, None, None,   122880      ['mixed4[0][0]']
#                                 160)
#
#  batch_normalization_44 (BatchN  (None, None, None,   480        ['conv2d_44[0][0]']
#  ormalization)                  160)
#
#  activation_44 (Activation)     (None, None, None,   0           ['batch_normalization_44[0][0]']
#                                 160)
#
#  conv2d_45 (Conv2D)             (None, None, None,   179200      ['activation_44[0][0]']
#                                 160)
#
#  batch_normalization_45 (BatchN  (None, None, None,   480        ['conv2d_45[0][0]']
#  ormalization)                  160)
#
#  activation_45 (Activation)     (None, None, None,   0           ['batch_normalization_45[0][0]']
#                                 160)
#
#  conv2d_41 (Conv2D)             (None, None, None,   122880      ['mixed4[0][0]']
#                                 160)
#
#  conv2d_46 (Conv2D)             (None, None, None,   179200      ['activation_45[0][0]']
#                                 160)
#
#  batch_normalization_41 (BatchN  (None, None, None,   480        ['conv2d_41[0][0]']
#  ormalization)                  160)
#
#  batch_normalization_46 (BatchN  (None, None, None,   480        ['conv2d_46[0][0]']
#  ormalization)                  160)
#
#  activation_41 (Activation)     (None, None, None,   0           ['batch_normalization_41[0][0]']
#                                 160)
#
#  activation_46 (Activation)     (None, None, None,   0           ['batch_normalization_46[0][0]']
#                                 160)
#
#  conv2d_42 (Conv2D)             (None, None, None,   179200      ['activation_41[0][0]']
#                                 160)
#
#  conv2d_47 (Conv2D)             (None, None, None,   179200      ['activation_46[0][0]']
#                                 160)
#
#  batch_normalization_42 (BatchN  (None, None, None,   480        ['conv2d_42[0][0]']
#  ormalization)                  160)
#
#  batch_normalization_47 (BatchN  (None, None, None,   480        ['conv2d_47[0][0]']
#  ormalization)                  160)
#
#  activation_42 (Activation)     (None, None, None,   0           ['batch_normalization_42[0][0]']
#                                 160)
#
#  activation_47 (Activation)     (None, None, None,   0           ['batch_normalization_47[0][0]']
#                                 160)
#
#  average_pooling2d_4 (AveragePo  (None, None, None,   0          ['mixed4[0][0]']
#  oling2D)                       768)
#
#  conv2d_40 (Conv2D)             (None, None, None,   147456      ['mixed4[0][0]']
#                                 192)
#
#  conv2d_43 (Conv2D)             (None, None, None,   215040      ['activation_42[0][0]']
#                                 192)
#
#  conv2d_48 (Conv2D)             (None, None, None,   215040      ['activation_47[0][0]']
#                                 192)
#
#  conv2d_49 (Conv2D)             (None, None, None,   147456      ['average_pooling2d_4[0][0]']
#                                 192)
#
#  batch_normalization_40 (BatchN  (None, None, None,   576        ['conv2d_40[0][0]']
#  ormalization)                  192)
#
#  batch_normalization_43 (BatchN  (None, None, None,   576        ['conv2d_43[0][0]']
# ...
#
#  conv2d_82 (Conv2D)             (None, None, None,   442368      ['activation_81[0][0]']
#                                 384)
#
#  conv2d_83 (Conv2D)             (None, None, None,   442368      ['activation_81[0][0]']
#                                 384)
#
#  average_pooling2d_7 (AveragePo  (None, None, None,   0          ['mixed8[0][0]']
#  oling2D)                       1280)
#
#  conv2d_76 (Conv2D)             (None, None, None,   409600      ['mixed8[0][0]']
#                                 320)
#
#  batch_normalization_78 (BatchN  (None, None, None,   1152       ['conv2d_78[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_79 (BatchN  (None, None, None,   1152       ['conv2d_79[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_82 (BatchN  (None, None, None,   1152       ['conv2d_82[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_83 (BatchN  (None, None, None,   1152       ['conv2d_83[0][0]']
#  ormalization)                  384)
#
#  conv2d_84 (Conv2D)             (None, None, None,   245760      ['average_pooling2d_7[0][0]']
#                                 192)
#
#  batch_normalization_76 (BatchN  (None, None, None,   960        ['conv2d_76[0][0]']
#  ormalization)                  320)
#
#  activation_78 (Activation)     (None, None, None,   0           ['batch_normalization_78[0][0]']
#                                 384)
#
#  activation_79 (Activation)     (None, None, None,   0           ['batch_normalization_79[0][0]']
#                                 384)
#
#  activation_82 (Activation)     (None, None, None,   0           ['batch_normalization_82[0][0]']
#                                 384)
#
#  activation_83 (Activation)     (None, None, None,   0           ['batch_normalization_83[0][0]']
#                                 384)
#
#  batch_normalization_84 (BatchN  (None, None, None,   576        ['conv2d_84[0][0]']
#  ormalization)                  192)
#
#  activation_76 (Activation)     (None, None, None,   0           ['batch_normalization_76[0][0]']
#                                 320)
#
#  mixed9_0 (Concatenate)         (None, None, None,   0           ['activation_78[0][0]',
#                                 768)                              'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, None, None,   0           ['activation_82[0][0]',
#                                 768)                              'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, None, None,   0           ['batch_normalization_84[0][0]']
#                                 192)
#
#  mixed9 (Concatenate)           (None, None, None,   0           ['activation_76[0][0]',
#                                 2048)                             'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)             (None, None, None,   917504      ['mixed9[0][0]']
#                                 448)
#
#  batch_normalization_89 (BatchN  (None, None, None,   1344       ['conv2d_89[0][0]']
#  ormalization)                  448)
#
#  activation_89 (Activation)     (None, None, None,   0           ['batch_normalization_89[0][0]']
#                                 448)
#
#  conv2d_86 (Conv2D)             (None, None, None,   786432      ['mixed9[0][0]']
#                                 384)
#
#  conv2d_90 (Conv2D)             (None, None, None,   1548288     ['activation_89[0][0]']
#                                 384)
#
#  batch_normalization_86 (BatchN  (None, None, None,   1152       ['conv2d_86[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_90 (BatchN  (None, None, None,   1152       ['conv2d_90[0][0]']
#  ormalization)                  384)
#
#  activation_86 (Activation)     (None, None, None,   0           ['batch_normalization_86[0][0]']
#                                 384)
#
#  activation_90 (Activation)     (None, None, None,   0           ['batch_normalization_90[0][0]']
#                                 384)
#
#  conv2d_87 (Conv2D)             (None, None, None,   442368      ['activation_86[0][0]']
#                                 384)
#
#  conv2d_88 (Conv2D)             (None, None, None,   442368      ['activation_86[0][0]']
#                                 384)
#
#  conv2d_91 (Conv2D)             (None, None, None,   442368      ['activation_90[0][0]']
#                                 384)
#
#  conv2d_92 (Conv2D)             (None, None, None,   442368      ['activation_90[0][0]']
#                                 384)
#
#  average_pooling2d_8 (AveragePo  (None, None, None,   0          ['mixed9[0][0]']
#  oling2D)                       2048)
#
#  conv2d_85 (Conv2D)             (None, None, None,   655360      ['mixed9[0][0]']
#                                 320)
#
#  batch_normalization_87 (BatchN  (None, None, None,   1152       ['conv2d_87[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_88 (BatchN  (None, None, None,   1152       ['conv2d_88[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_91 (BatchN  (None, None, None,   1152       ['conv2d_91[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_92 (BatchN  (None, None, None,   1152       ['conv2d_92[0][0]']
#  ormalization)                  384)
#
#  conv2d_93 (Conv2D)             (None, None, None,   393216      ['average_pooling2d_8[0][0]']
#                                 192)
#
#  batch_normalization_85 (BatchN  (None, None, None,   960        ['conv2d_85[0][0]']
#  ormalization)                  320)
#
#  activation_87 (Activation)     (None, None, None,   0           ['batch_normalization_87[0][0]']
#                                 384)
#
#  activation_88 (Activation)     (None, None, None,   0           ['batch_normalization_88[0][0]']
#                                 384)
#
#  activation_91 (Activation)     (None, None, None,   0           ['batch_normalization_91[0][0]']
#                                 384)
#
#  activation_92 (Activation)     (None, None, None,   0           ['batch_normalization_92[0][0]']
#                                 384)
#
#  batch_normalization_93 (BatchN  (None, None, None,   576        ['conv2d_93[0][0]']
#  ormalization)                  192)
#
#  activation_85 (Activation)     (None, None, None,   0           ['batch_normalization_85[0][0]']
#                                 320)
#
#  mixed9_1 (Concatenate)         (None, None, None,   0           ['activation_87[0][0]',
#                                 768)                              'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, None, None,   0           ['activation_91[0][0]',
#                                 768)                              'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, None, None,   0           ['batch_normalization_93[0][0]']
#                                 192)
#
#  mixed10 (Concatenate)          (None, None, None,   0           ['activation_85[0][0]',
#                                 2048)                             'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
# Created main layers for end inceptionV3 model
x = pretrained_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
x = Dense(512)(x)
x = Activation('relu')(x)
predictions = Dense(4, activation='softmax')(x)
model = Model(inputs=pretrained_model.input, outputs=predictions)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv2d (Conv2D)                (None, None, None,   864         ['input_1[0][0]']
#                                 32)
#
#  batch_normalization (BatchNorm  (None, None, None,   96         ['conv2d[0][0]']
#  alization)                     32)
#
#  activation (Activation)        (None, None, None,   0           ['batch_normalization[0][0]']
#                                 32)
#
#  conv2d_1 (Conv2D)              (None, None, None,   9216        ['activation[0][0]']
#                                 32)
#
#  batch_normalization_1 (BatchNo  (None, None, None,   96         ['conv2d_1[0][0]']
#  rmalization)                   32)
#
#  activation_1 (Activation)      (None, None, None,   0           ['batch_normalization_1[0][0]']
#                                 32)
#
#  conv2d_2 (Conv2D)              (None, None, None,   18432       ['activation_1[0][0]']
#                                 64)
#
#  batch_normalization_2 (BatchNo  (None, None, None,   192        ['conv2d_2[0][0]']
#  rmalization)                   64)
#
#  activation_2 (Activation)      (None, None, None,   0           ['batch_normalization_2[0][0]']
#                                 64)
#
#  max_pooling2d (MaxPooling2D)   (None, None, None,   0           ['activation_2[0][0]']
#                                 64)
#
#  conv2d_3 (Conv2D)              (None, None, None,   5120        ['max_pooling2d[0][0]']
#                                 80)
#
#  batch_normalization_3 (BatchNo  (None, None, None,   240        ['conv2d_3[0][0]']
#  rmalization)                   80)
#
#  activation_3 (Activation)      (None, None, None,   0           ['batch_normalization_3[0][0]']
#                                 80)
#
#  conv2d_4 (Conv2D)              (None, None, None,   138240      ['activation_3[0][0]']
#                                 192)
#
#  batch_normalization_4 (BatchNo  (None, None, None,   576        ['conv2d_4[0][0]']
#  rmalization)                   192)
#
#  activation_4 (Activation)      (None, None, None,   0           ['batch_normalization_4[0][0]']
#                                 192)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, None, None,   0          ['activation_4[0][0]']
#                                 192)
#
#  conv2d_8 (Conv2D)              (None, None, None,   12288       ['max_pooling2d_1[0][0]']
#                                 64)
#
#  batch_normalization_8 (BatchNo  (None, None, None,   192        ['conv2d_8[0][0]']
#  rmalization)                   64)
#
#  activation_8 (Activation)      (None, None, None,   0           ['batch_normalization_8[0][0]']
#                                 64)
#
#  conv2d_6 (Conv2D)              (None, None, None,   9216        ['max_pooling2d_1[0][0]']
#                                 48)
#
#  conv2d_9 (Conv2D)              (None, None, None,   55296       ['activation_8[0][0]']
#                                 96)
#
#  batch_normalization_6 (BatchNo  (None, None, None,   144        ['conv2d_6[0][0]']
#  rmalization)                   48)
#
#  batch_normalization_9 (BatchNo  (None, None, None,   288        ['conv2d_9[0][0]']
#  rmalization)                   96)
#
#  activation_6 (Activation)      (None, None, None,   0           ['batch_normalization_6[0][0]']
#                                 48)
#
#  activation_9 (Activation)      (None, None, None,   0           ['batch_normalization_9[0][0]']
#                                 96)
#
#  average_pooling2d (AveragePool  (None, None, None,   0          ['max_pooling2d_1[0][0]']
#  ing2D)                         192)
#
#  conv2d_5 (Conv2D)              (None, None, None,   12288       ['max_pooling2d_1[0][0]']
#                                 64)
#
#  conv2d_7 (Conv2D)              (None, None, None,   76800       ['activation_6[0][0]']
#                                 64)
#
#  conv2d_10 (Conv2D)             (None, None, None,   82944       ['activation_9[0][0]']
#                                 96)
#
#  conv2d_11 (Conv2D)             (None, None, None,   6144        ['average_pooling2d[0][0]']
#                                 32)
#
#  batch_normalization_5 (BatchNo  (None, None, None,   192        ['conv2d_5[0][0]']
#  rmalization)                   64)
#
#  batch_normalization_7 (BatchNo  (None, None, None,   192        ['conv2d_7[0][0]']
#  rmalization)                   64)
#
#  batch_normalization_10 (BatchN  (None, None, None,   288        ['conv2d_10[0][0]']
#  ormalization)                  96)
#
#  batch_normalization_11 (BatchN  (None, None, None,   96         ['conv2d_11[0][0]']
#  ormalization)                  32)
#
#  activation_5 (Activation)      (None, None, None,   0           ['batch_normalization_5[0][0]']
#                                 64)
#
#  activation_7 (Activation)      (None, None, None,   0           ['batch_normalization_7[0][0]']
#                                 64)
#
#  activation_10 (Activation)     (None, None, None,   0           ['batch_normalization_10[0][0]']
#                                 96)
#
#  activation_11 (Activation)     (None, None, None,   0           ['batch_normalization_11[0][0]']
#                                 32)
#
#  mixed0 (Concatenate)           (None, None, None,   0           ['activation_5[0][0]',
#                                 256)                              'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, None, None,   16384       ['mixed0[0][0]']
#                                 64)
#
#  batch_normalization_15 (BatchN  (None, None, None,   192        ['conv2d_15[0][0]']
#  ormalization)                  64)
#
#  activation_15 (Activation)     (None, None, None,   0           ['batch_normalization_15[0][0]']
#                                 64)
#
#  conv2d_13 (Conv2D)             (None, None, None,   12288       ['mixed0[0][0]']
#                                 48)
#
#  conv2d_16 (Conv2D)             (None, None, None,   55296       ['activation_15[0][0]']
#                                 96)
#
#  batch_normalization_13 (BatchN  (None, None, None,   144        ['conv2d_13[0][0]']
#  ormalization)                  48)
#
#  batch_normalization_16 (BatchN  (None, None, None,   288        ['conv2d_16[0][0]']
#  ormalization)                  96)
#
#  activation_13 (Activation)     (None, None, None,   0           ['batch_normalization_13[0][0]']
#                                 48)
#
#  activation_16 (Activation)     (None, None, None,   0           ['batch_normalization_16[0][0]']
#                                 96)
#
#  average_pooling2d_1 (AveragePo  (None, None, None,   0          ['mixed0[0][0]']
#  oling2D)                       256)
#
#  conv2d_12 (Conv2D)             (None, None, None,   16384       ['mixed0[0][0]']
#                                 64)
#
#  conv2d_14 (Conv2D)             (None, None, None,   76800       ['activation_13[0][0]']
#                                 64)
#
#  conv2d_17 (Conv2D)             (None, None, None,   82944       ['activation_16[0][0]']
#                                 96)
#
#  conv2d_18 (Conv2D)             (None, None, None,   16384       ['average_pooling2d_1[0][0]']
#                                 64)
#
#  batch_normalization_12 (BatchN  (None, None, None,   192        ['conv2d_12[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_14 (BatchN  (None, None, None,   192        ['conv2d_14[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_17 (BatchN  (None, None, None,   288        ['conv2d_17[0][0]']
#  ormalization)                  96)
#
#  batch_normalization_18 (BatchN  (None, None, None,   192        ['conv2d_18[0][0]']
#  ormalization)                  64)
#
#  activation_12 (Activation)     (None, None, None,   0           ['batch_normalization_12[0][0]']
#                                 64)
#
#  activation_14 (Activation)     (None, None, None,   0           ['batch_normalization_14[0][0]']
#                                 64)
#
#  activation_17 (Activation)     (None, None, None,   0           ['batch_normalization_17[0][0]']
#                                 96)
#
#  activation_18 (Activation)     (None, None, None,   0           ['batch_normalization_18[0][0]']
#                                 64)
#
#  mixed1 (Concatenate)           (None, None, None,   0           ['activation_12[0][0]',
#                                 288)                              'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, None, None,   18432       ['mixed1[0][0]']
#                                 64)
#
#  batch_normalization_22 (BatchN  (None, None, None,   192        ['conv2d_22[0][0]']
#  ormalization)                  64)
#
#  activation_22 (Activation)     (None, None, None,   0           ['batch_normalization_22[0][0]']
#                                 64)
#
#  conv2d_20 (Conv2D)             (None, None, None,   13824       ['mixed1[0][0]']
#                                 48)
#
#  conv2d_23 (Conv2D)             (None, None, None,   55296       ['activation_22[0][0]']
#                                 96)
#
#  batch_normalization_20 (BatchN  (None, None, None,   144        ['conv2d_20[0][0]']
#  ormalization)                  48)
#
#  batch_normalization_23 (BatchN  (None, None, None,   288        ['conv2d_23[0][0]']
#  ormalization)                  96)
#
#  activation_20 (Activation)     (None, None, None,   0           ['batch_normalization_20[0][0]']
#                                 48)
#
#  activation_23 (Activation)     (None, None, None,   0           ['batch_normalization_23[0][0]']
#                                 96)
#
#  average_pooling2d_2 (AveragePo  (None, None, None,   0          ['mixed1[0][0]']
#  oling2D)                       288)
#
#  conv2d_19 (Conv2D)             (None, None, None,   18432       ['mixed1[0][0]']
#                                 64)
#
#  conv2d_21 (Conv2D)             (None, None, None,   76800       ['activation_20[0][0]']
#                                 64)
#
#  conv2d_24 (Conv2D)             (None, None, None,   82944       ['activation_23[0][0]']
#                                 96)
#
#  conv2d_25 (Conv2D)             (None, None, None,   18432       ['average_pooling2d_2[0][0]']
#                                 64)
#
#  batch_normalization_19 (BatchN  (None, None, None,   192        ['conv2d_19[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_21 (BatchN  (None, None, None,   192        ['conv2d_21[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_24 (BatchN  (None, None, None,   288        ['conv2d_24[0][0]']
#  ormalization)                  96)
#
#  batch_normalization_25 (BatchN  (None, None, None,   192        ['conv2d_25[0][0]']
#  ormalization)                  64)
#
#  activation_19 (Activation)     (None, None, None,   0           ['batch_normalization_19[0][0]']
#                                 64)
#
#  activation_21 (Activation)     (None, None, None,   0           ['batch_normalization_21[0][0]']
#                                 64)
#
#  activation_24 (Activation)     (None, None, None,   0           ['batch_normalization_24[0][0]']
#                                 96)
#
#  activation_25 (Activation)     (None, None, None,   0           ['batch_normalization_25[0][0]']
#                                 64)
#
#  mixed2 (Concatenate)           (None, None, None,   0           ['activation_19[0][0]',
#                                 288)                              'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, None, None,   18432       ['mixed2[0][0]']
#                                 64)
#
#  batch_normalization_27 (BatchN  (None, None, None,   192        ['conv2d_27[0][0]']
#  ormalization)                  64)
#
#  activation_27 (Activation)     (None, None, None,   0           ['batch_normalization_27[0][0]']
#                                 64)
#
#  conv2d_28 (Conv2D)             (None, None, None,   55296       ['activation_27[0][0]']
#                                 96)
#
#  batch_normalization_28 (BatchN  (None, None, None,   288        ['conv2d_28[0][0]']
#  ormalization)                  96)
#
#  activation_28 (Activation)     (None, None, None,   0           ['batch_normalization_28[0][0]']
#                                 96)
#
#  conv2d_26 (Conv2D)             (None, None, None,   995328      ['mixed2[0][0]']
#                                 384)
#
#  conv2d_29 (Conv2D)             (None, None, None,   82944       ['activation_28[0][0]']
#                                 96)
#
#  batch_normalization_26 (BatchN  (None, None, None,   1152       ['conv2d_26[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_29 (BatchN  (None, None, None,   288        ['conv2d_29[0][0]']
#  ormalization)                  96)
#
#  activation_26 (Activation)     (None, None, None,   0           ['batch_normalization_26[0][0]']
#                                 384)
#
#  activation_29 (Activation)     (None, None, None,   0           ['batch_normalization_29[0][0]']
#                                 96)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, None, None,   0          ['mixed2[0][0]']
#                                 288)
#
#  mixed3 (Concatenate)           (None, None, None,   0           ['activation_26[0][0]',
#                                 768)                              'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, None, None,   98304       ['mixed3[0][0]']
#                                 128)
#
#  batch_normalization_34 (BatchN  (None, None, None,   384        ['conv2d_34[0][0]']
#  ormalization)                  128)
#
#  activation_34 (Activation)     (None, None, None,   0           ['batch_normalization_34[0][0]']
#                                 128)
#
#  conv2d_35 (Conv2D)             (None, None, None,   114688      ['activation_34[0][0]']
#                                 128)
#
#  batch_normalization_35 (BatchN  (None, None, None,   384        ['conv2d_35[0][0]']
#  ormalization)                  128)
#
#  activation_35 (Activation)     (None, None, None,   0           ['batch_normalization_35[0][0]']
#                                 128)
#
#  conv2d_31 (Conv2D)             (None, None, None,   98304       ['mixed3[0][0]']
#                                 128)
#
#  conv2d_36 (Conv2D)             (None, None, None,   114688      ['activation_35[0][0]']
#                                 128)
#
#  batch_normalization_31 (BatchN  (None, None, None,   384        ['conv2d_31[0][0]']
#  ormalization)                  128)
#
#  batch_normalization_36 (BatchN  (None, None, None,   384        ['conv2d_36[0][0]']
#  ormalization)                  128)
#
#  activation_31 (Activation)     (None, None, None,   0           ['batch_normalization_31[0][0]']
#                                 128)
#
#  activation_36 (Activation)     (None, None, None,   0           ['batch_normalization_36[0][0]']
#                                 128)
#
#  conv2d_32 (Conv2D)             (None, None, None,   114688      ['activation_31[0][0]']
#                                 128)
#
#  conv2d_37 (Conv2D)             (None, None, None,   114688      ['activation_36[0][0]']
#                                 128)
#
#  batch_normalization_32 (BatchN  (None, None, None,   384        ['conv2d_32[0][0]']
#  ormalization)                  128)
#
#  batch_normalization_37 (BatchN  (None, None, None,   384        ['conv2d_37[0][0]']
#  ormalization)                  128)
#
#  activation_32 (Activation)     (None, None, None,   0           ['batch_normalization_32[0][0]']
#                                 128)
#
#  activation_37 (Activation)     (None, None, None,   0           ['batch_normalization_37[0][0]']
#                                 128)
#
#  average_pooling2d_3 (AveragePo  (None, None, None,   0          ['mixed3[0][0]']
#  oling2D)                       768)
#
#  conv2d_30 (Conv2D)             (None, None, None,   147456      ['mixed3[0][0]']
#                                 192)
#
#  conv2d_33 (Conv2D)             (None, None, None,   172032      ['activation_32[0][0]']
#                                 192)
#
#  conv2d_38 (Conv2D)             (None, None, None,   172032      ['activation_37[0][0]']
#                                 192)
#
#  conv2d_39 (Conv2D)             (None, None, None,   147456      ['average_pooling2d_3[0][0]']
#                                 192)
#
#  batch_normalization_30 (BatchN  (None, None, None,   576        ['conv2d_30[0][0]']
#  ormalization)                  192)
#
#  batch_normalization_33 (BatchN  (None, None, None,   576        ['conv2d_33[0][0]']
#  ormalization)                  192)
#
#  batch_normalization_38 (BatchN  (None, None, None,   576        ['conv2d_38[0][0]']
#  ormalization)                  192)
#
#  batch_normalization_39 (BatchN  (None, None, None,   576        ['conv2d_39[0][0]']
#  ormalization)                  192)
#
#  activation_30 (Activation)     (None, None, None,   0           ['batch_normalization_30[0][0]']
#                                 192)
#
#  activation_33 (Activation)     (None, None, None,   0           ['batch_normalization_33[0][0]']
#                                 192)
#
#  activation_38 (Activation)     (None, None, None,   0           ['batch_normalization_38[0][0]']
#                                 192)
#
#  activation_39 (Activation)     (None, None, None,   0           ['batch_normalization_39[0][0]']
#                                 192)
#
#  mixed4 (Concatenate)           (None, None, None,   0           ['activation_30[0][0]',
#                                 768)                              'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, None, None,   122880      ['mixed4[0][0]']
#                                 160)
#
#  batch_normalization_44 (BatchN  (None, None, None,   480        ['conv2d_44[0][0]']
#  ormalization)                  160)
#
#  activation_44 (Activation)     (None, None, None,   0           ['batch_normalization_44[0][0]']
#                                 160)
#
#  conv2d_45 (Conv2D)             (None, None, None,   179200      ['activation_44[0][0]']
#                                 160)
#
#  batch_normalization_45 (BatchN  (None, None, None,   480        ['conv2d_45[0][0]']
#  ormalization)                  160)
#
#  activation_45 (Activation)     (None, None, None,   0           ['batch_normalization_45[0][0]']
#                                 160)
#
#  conv2d_41 (Conv2D)             (None, None, None,   122880      ['mixed4[0][0]']
#                                 160)
#
#  conv2d_46 (Conv2D)             (None, None, None,   179200      ['activation_45[0][0]']
#                                 160)
#
#  batch_normalization_41 (BatchN  (None, None, None,   480        ['conv2d_41[0][0]']
#  ormalization)                  160)
#
#  batch_normalization_46 (BatchN  (None, None, None,   480        ['conv2d_46[0][0]']
#  ormalization)                  160)
#
#  activation_41 (Activation)     (None, None, None,   0           ['batch_normalization_41[0][0]']
#                                 160)
#
#  activation_46 (Activation)     (None, None, None,   0           ['batch_normalization_46[0][0]']
#                                 160)
#
#  conv2d_42 (Conv2D)             (None, None, None,   179200      ['activation_41[0][0]']
#                                 160)
#
#  conv2d_47 (Conv2D)             (None, None, None,   179200      ['activation_46[0][0]']
#                                 160)
#
#  batch_normalization_42 (BatchN  (None, None, None,   480        ['conv2d_42[0][0]']
#  ormalization)                  160)
#
#  batch_normalization_47 (BatchN  (None, None, None,   480        ['conv2d_47[0][0]']
#  ormalization)                  160)
#
#  activation_42 (Activation)     (None, None, None,   0           ['batch_normalization_42[0][0]']
#                                 160)
#
#  activation_47 (Activation)     (None, None, None,   0           ['batch_normalization_47[0][0]']
#                                 160)
#
#  average_pooling2d_4 (AveragePo  (None, None, None,   0          ['mixed4[0][0]']
#  oling2D)                       768)
#
#  conv2d_40 (Conv2D)             (None, None, None,   147456      ['mixed4[0][0]']
#                                 192)
#
#  conv2d_43 (Conv2D)             (None, None, None,   215040      ['activation_42[0][0]']
#                                 192)
#
#  conv2d_48 (Conv2D)             (None, None, None,   215040      ['activation_47[0][0]']
#                                 192)
#
#  conv2d_49 (Conv2D)             (None, None, None,   147456      ['average_pooling2d_4[0][0]']
#                                 192)
#
#  batch_normalization_40 (BatchN  (None, None, None,   576        ['conv2d_40[0][0]']
#  ormalization)                  192)
#
#  batch_normalization_43 (BatchN  (None, None, None,   576        ['conv2d_43[0][0]']
# ...
#  batch_normalization_82 (BatchN  (None, None, None,   1152       ['conv2d_82[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_83 (BatchN  (None, None, None,   1152       ['conv2d_83[0][0]']
#  ormalization)                  384)
#
#  conv2d_84 (Conv2D)             (None, None, None,   245760      ['average_pooling2d_7[0][0]']
#                                 192)
#
#  batch_normalization_76 (BatchN  (None, None, None,   960        ['conv2d_76[0][0]']
#  ormalization)                  320)
#
#  activation_78 (Activation)     (None, None, None,   0           ['batch_normalization_78[0][0]']
#                                 384)
#
#  activation_79 (Activation)     (None, None, None,   0           ['batch_normalization_79[0][0]']
#                                 384)
#
#  activation_82 (Activation)     (None, None, None,   0           ['batch_normalization_82[0][0]']
#                                 384)
#
#  activation_83 (Activation)     (None, None, None,   0           ['batch_normalization_83[0][0]']
#                                 384)
#
#  batch_normalization_84 (BatchN  (None, None, None,   576        ['conv2d_84[0][0]']
#  ormalization)                  192)
#
#  activation_76 (Activation)     (None, None, None,   0           ['batch_normalization_76[0][0]']
#                                 320)
#
#  mixed9_0 (Concatenate)         (None, None, None,   0           ['activation_78[0][0]',
#                                 768)                              'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, None, None,   0           ['activation_82[0][0]',
#                                 768)                              'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, None, None,   0           ['batch_normalization_84[0][0]']
#                                 192)
#
#  mixed9 (Concatenate)           (None, None, None,   0           ['activation_76[0][0]',
#                                 2048)                             'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)             (None, None, None,   917504      ['mixed9[0][0]']
#                                 448)
#
#  batch_normalization_89 (BatchN  (None, None, None,   1344       ['conv2d_89[0][0]']
#  ormalization)                  448)
#
#  activation_89 (Activation)     (None, None, None,   0           ['batch_normalization_89[0][0]']
#                                 448)
#
#  conv2d_86 (Conv2D)             (None, None, None,   786432      ['mixed9[0][0]']
#                                 384)
#
#  conv2d_90 (Conv2D)             (None, None, None,   1548288     ['activation_89[0][0]']
#                                 384)
#
#  batch_normalization_86 (BatchN  (None, None, None,   1152       ['conv2d_86[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_90 (BatchN  (None, None, None,   1152       ['conv2d_90[0][0]']
#  ormalization)                  384)
#
#  activation_86 (Activation)     (None, None, None,   0           ['batch_normalization_86[0][0]']
#                                 384)
#
#  activation_90 (Activation)     (None, None, None,   0           ['batch_normalization_90[0][0]']
#                                 384)
#
#  conv2d_87 (Conv2D)             (None, None, None,   442368      ['activation_86[0][0]']
#                                 384)
#
#  conv2d_88 (Conv2D)             (None, None, None,   442368      ['activation_86[0][0]']
#                                 384)
#
#  conv2d_91 (Conv2D)             (None, None, None,   442368      ['activation_90[0][0]']
#                                 384)
#
#  conv2d_92 (Conv2D)             (None, None, None,   442368      ['activation_90[0][0]']
#                                 384)
#
#  average_pooling2d_8 (AveragePo  (None, None, None,   0          ['mixed9[0][0]']
#  oling2D)                       2048)
#
#  conv2d_85 (Conv2D)             (None, None, None,   655360      ['mixed9[0][0]']
#                                 320)
#
#  batch_normalization_87 (BatchN  (None, None, None,   1152       ['conv2d_87[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_88 (BatchN  (None, None, None,   1152       ['conv2d_88[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_91 (BatchN  (None, None, None,   1152       ['conv2d_91[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_92 (BatchN  (None, None, None,   1152       ['conv2d_92[0][0]']
#  ormalization)                  384)
#
#  conv2d_93 (Conv2D)             (None, None, None,   393216      ['average_pooling2d_8[0][0]']
#                                 192)
#
#  batch_normalization_85 (BatchN  (None, None, None,   960        ['conv2d_85[0][0]']
#  ormalization)                  320)
#
#  activation_87 (Activation)     (None, None, None,   0           ['batch_normalization_87[0][0]']
#                                 384)
#
#  activation_88 (Activation)     (None, None, None,   0           ['batch_normalization_88[0][0]']
#                                 384)
#
#  activation_91 (Activation)     (None, None, None,   0           ['batch_normalization_91[0][0]']
#                                 384)
#
#  activation_92 (Activation)     (None, None, None,   0           ['batch_normalization_92[0][0]']
#                                 384)
#
#  batch_normalization_93 (BatchN  (None, None, None,   576        ['conv2d_93[0][0]']
#  ormalization)                  192)
#
#  activation_85 (Activation)     (None, None, None,   0           ['batch_normalization_85[0][0]']
#                                 320)
#
#  mixed9_1 (Concatenate)         (None, None, None,   0           ['activation_87[0][0]',
#                                 768)                              'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, None, None,   0           ['activation_91[0][0]',
#                                 768)                              'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, None, None,   0           ['batch_normalization_93[0][0]']
#                                 192)
#
#  mixed10 (Concatenate)          (None, None, None,   0           ['activation_85[0][0]',
#                                 2048)                             'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 2048)        0           ['mixed10[0][0]']
#  obalAveragePooling2D)
#
#  dense_3 (Dense)                (None, 1024)         2098176     ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  batch_normalization_95 (BatchN  (None, 1024)        4096        ['dense_3[0][0]']
#  ormalization)
#
#  activation_96 (Activation)     (None, 1024)         0           ['batch_normalization_95[0][0]']
#
#  dropout_1 (Dropout)            (None, 1024)         0           ['activation_96[0][0]']
#
#  dense_4 (Dense)                (None, 512)          524800      ['dropout_1[0][0]']
#
#  activation_97 (Activation)     (None, 512)          0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 4)            2052        ['activation_97[0][0]']
#
# ==================================================================================================
# Total params: 24,431,908
# Trainable params: 2,627,076
# Non-trainable params: 21,804,832
# __________________________________________________________________________________________________

# %%
# Train a composite neural network based on InceptionV3
model.compile(loss='categorical_crossentropy',
              optimizer='adam', 
              metrics=['accuracy'])

filepath="inceptionv3_best.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min')
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=10, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)
callbacks_list = [checkpoint, learning_rate_reduction]

steps_per_epoch = 40
history = model.fit_generator(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    validation_data=test_generator,
    validation_steps=5,
    callbacks=callbacks_list,
    epochs=7,
    verbose=2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/7
#
# Epoch 1: val_loss improved from inf to 2.31189, saving model to inceptionv3_best.h5
# 40/40 - 55s - loss: 1.5398 - accuracy: 0.4148 - val_loss: 2.3119 - val_accuracy: 0.3750 - lr: 0.0010 - 55s/epoch - 1s/step
# Epoch 2/7
#
# Epoch 2: val_loss improved from 2.31189 to 1.39234, saving model to inceptionv3_best.h5
# 40/40 - 47s - loss: 1.1742 - accuracy: 0.5148 - val_loss: 1.3923 - val_accuracy: 0.3812 - lr: 0.0010 - 47s/epoch - 1s/step
# Epoch 3/7
#
# Epoch 3: val_loss improved from 1.39234 to 1.20441, saving model to inceptionv3_best.h5
# 40/40 - 48s - loss: 1.0897 - accuracy: 0.5289 - val_loss: 1.2044 - val_accuracy: 0.4812 - lr: 0.0010 - 48s/epoch - 1s/step
# Epoch 4/7
#
# Epoch 4: val_loss did not improve from 1.20441
# 40/40 - 46s - loss: 1.0526 - accuracy: 0.5695 - val_loss: 1.2497 - val_accuracy: 0.4187 - lr: 0.0010 - 46s/epoch - 1s/step
# Epoch 5/7
#
# Epoch 5: val_loss improved from 1.20441 to 1.10107, saving model to inceptionv3_best.h5
# 40/40 - 48s - loss: 0.9930 - accuracy: 0.5883 - val_loss: 1.1011 - val_accuracy: 0.4688 - lr: 0.0010 - 48s/epoch - 1s/step
# Epoch 6/7
#
# Epoch 6: val_loss did not improve from 1.10107
# 40/40 - 46s - loss: 0.9902 - accuracy: 0.5813 - val_loss: 1.1262 - val_accuracy: 0.4750 - lr: 0.0010 - 46s/epoch - 1s/step
# Epoch 7/7
#
# Epoch 7: val_loss did not improve from 1.10107
# 40/40 - 46s - loss: 1.0034 - accuracy: 0.5781 - val_loss: 1.1391 - val_accuracy: 0.4750 - lr: 0.0010 - 46s/epoch - 1s/step

# %%
test_score = model.evaluate_generator(test_generator, batch_size)

print("[INFO] accuracy: {:.2f}%".format(test_score[1] * 100)) 
print("[INFO] Loss: ",test_score[0])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   """Entry point for launching an IPython kernel.
# [INFO] accuracy: 45.21%
# [INFO] Loss:  1.1679103374481201

# %%
from matplotlib import cm
import matplotlib.cm as cm
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(20,20))

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

#Print the Target names
from sklearn.metrics import classification_report, confusion_matrix
import itertools 
#shuffle=False

target_names = []
for key in train_generator.class_indices:
    target_names.append(key)

# print(target_names)

#Confution Matrix 

Y_pred = model.predict_generator(test_generator)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
cm = confusion_matrix(test_generator.classes, y_pred)
plot_confusion_matrix(cm, target_names, title='Confusion Matrix')

#Print Classification Report
print('Classification Report')
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# Confusion Matrix
# Normalized confusion matrix
# Classification Report
#               precision    recall  f1-score   support
#
#   camionette       0.23      0.13      0.17       890
#      fourgon       0.26      0.48      0.33       890
#      porteur       0.25      0.16      0.20       890
#   utilitaire       0.26      0.24      0.25       890
#
#     accuracy                           0.25      3560
#    macro avg       0.25      0.25      0.24      3560
# weighted avg       0.25      0.25      0.24      3560

# %%
##Plot the Graph

# Loss Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
  
# Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'r',linewidth=3.0)
plt.plot(history.history['val_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %%
img_path = '/content/truck_recommandation/dataset/single_prediction/images (2).jpg'

img = image.load_img(img_path, target_size=(128, 128))
plt.imshow(img)
plt.show()

# %%
x = image.img_to_array(img)
x /= 255
x = np.expand_dims(x, axis=0)

# %%
prediction = model.predict(x)

# %%
prediction
# Out:
# array([[0.05131766, 0.5456936 , 0.02296335, 0.38002545]], dtype=float32)

# %%
classes = np.argmax(prediction, axis = 1)
print(classes)
# Out:
# [1]
